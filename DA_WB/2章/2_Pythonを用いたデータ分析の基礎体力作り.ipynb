# %% [markdown]
# #2-2.データを読み込んでみよう

# %%
# 必要なライブラリをインポート
from google.colab import drive
import os

# Googleドライブをマウント
drive.mount('/content/drive')

# データフォルダに移動
data_folder = '/content/drive/My Drive/DA_WB/2章/data'
os.chdir(data_folder)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df_sales_2021 = pd.read_csv('売上テーブル_2021.csv', encoding='Sjis')
df_sales_2021.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_0['売上'].plot(kind='hist', bins=20, title='売上')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('売上ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 39015 (\N{CJK UNIFIED IDEOGRAPH-9867}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('顧客ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22865 (\N{CJK UNIFIED IDEOGRAPH-5951}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 32004 (\N{CJK UNIFIED IDEOGRAPH-7D04}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('契約ID').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# _df_4['売上'].plot(kind='line', figsize=(8, 4), title='売上')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 39015 (\N{CJK UNIFIED IDEOGRAPH-9867}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['顧客ID'].value_counts()
#     for x_label, grp in _df_5.groupby('売上ID')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('売上ID')
# _ = plt.ylabel('顧客ID')
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 39015 (\N{CJK UNIFIED IDEOGRAPH-9867}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22865 (\N{CJK UNIFIED IDEOGRAPH-5951}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 32004 (\N{CJK UNIFIED IDEOGRAPH-7D04}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['契約ID'].value_counts()
#     for x_label, grp in _df_6.groupby('顧客ID')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('顧客ID')
# _ = plt.ylabel('契約ID')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_7['売上ID'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_7, x='売上', y='売上ID', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 39015 (\N{CJK UNIFIED IDEOGRAPH-9867}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 23458 (\N{CJK UNIFIED IDEOGRAPH-5BA2}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['顧客ID'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='売上', y='顧客ID', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22770 (\N{CJK UNIFIED IDEOGRAPH-58F2}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 19978 (\N{CJK UNIFIED IDEOGRAPH-4E0A}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 22865 (\N{CJK UNIFIED IDEOGRAPH-5951}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 32004 (\N{CJK UNIFIED IDEOGRAPH-7D04}) missing from current font.
#   plt.savefig(
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['契約ID'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='売上', y='契約ID', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df_sales_2022 = pd.read_csv('売上テーブル_2022.csv', encoding='Sjis')
df_sales_2022.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日     売上
# 0  S-1125052  C-1000892  N-1001965  2022/1/1  29000
# 1  S-1125053  C-1001352  N-1003792  2022/1/1  10000
# 2  S-1125054  C-1000547  N-1000944  2022/1/1  30000
# 3  S-1125055  C-1000072  N-1000075  2022/1/1  10000
# 4  S-1125056  C-1000222  N-1000275  2022/1/1  50000

# %%
df_customer = pd.read_csv('顧客テーブル.csv', encoding='Sjis')
df_customer.head()
# Out:
#         顧客ID   顧客区分         顧客名    地域 都道府県 市区町村      初回契約日    社員ID  顧客満足度
# 0  C-1000007  企業規模小    株式会社鈴木工業  関東地方  東京都  台東区   2015/1/9  101782      3
# 1  C-1000008    その他    株式会社中村工業    四国  徳島県  徳島市  2015/1/15  100726      3
# 2  C-1000009  企業規模中  大和屋根工事合同会社  関西地方  三重県   津市  2015/1/19  101305      2
# 3  C-1000010  企業規模大     株式会社ユタカ  関東地方  千葉県  松戸市  2015/1/19  107576      5
# 4  C-1000011  企業規模中    合資会社橋本商店  関東地方  東京都  大田区  2015/1/21  103152      1

# %%
ds_sales = pd.concat([df_sales_2021, df_sales_2022], ignore_index=True)
ds_sales.head()
# Out:
#         売上ID       顧客ID       契約ID       売上日       売上
# 0  S-1000072  C-1000222  N-1002716  2021/1/1   6000.0
# 1  S-1000073  C-1000458  N-1000683  2021/1/1  50000.0
# 2  S-1000074  C-1000599  N-1001044  2021/1/1  10000.0
# 3  S-1000075  C-1000599  N-1001042  2021/1/1  10000.0
# 4  S-1000076  C-1000599  N-1001041  2021/1/1  10000.0

# %%
ds_sales.tail()
# Out:
#             売上ID       顧客ID       契約ID         売上日       売上
# 75440  S-1177220  C-1001260  N-1004684  2022/12/30   9000.0
# 75441  S-1177223  C-1000315  N-1004170  2022/12/30  21000.0
# 75442  S-1177224  C-1000094  N-1004169  2022/12/30  15000.0
# 75443  S-1177234  C-1001645  N-1004605  2022/12/30  13000.0
# 75444  S-1177235  C-1001714  N-1004814  2022/12/31  50000.0

# %% [markdown]
# #2-3.データを結合してみよう

# %% [markdown]
# #2-4.データの基本的な特性を把握しよう

# %% [markdown]
# #2-5.欠損値/異常値を処理してデータを綺麗にしよう

# %% [markdown]
# #2-6.データ取り扱いの注意点とよく使う処理を押さえよう

# %% [markdown]
# ##■データ取り扱いの注意点を押さえよう

# %% [markdown]
# ##■よく利用する処理を押さえよう

# %% [markdown]
# #2-7.集計・可視化・データ出力をしてみよう
